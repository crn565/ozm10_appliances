# %% [markdown]
# # Carga de datos capturados con el OZM

# %% [markdown]
# ## Primeros analisis de cargas de datos ¶
# En primer lugar, se analizan metadatos y datos del dataset cuya estructura deberia basarse en el formato NILMTK-DF.
#
# Contemos el numero de filas de cada fichero de datos en formato parquet

# %%
import pandas as pd

# %%
with open(r'.\data\ozm1\ozm_fan_200MS.parquet', 'rb') as f:
    df = pd.read_parquet(f, engine='pyarrow')
print ('filas fichero fan=',len(df.index))
# Out:
# filas fichero fan= 36476

# %%
with open(r'.\data\ozm1\ozm_freezer_200MS.parquet', 'rb') as f:
    df = pd.read_parquet(f, engine='pyarrow')
print ('filas fichero freezer=',len(df.index))
# Out:
# filas fichero freezer= 36477

# %%
with open(r'.\data\ozm1\ozm_fridge_200MS.parquet', 'rb') as f:
    df = pd.read_parquet(f, engine='pyarrow')
print ('filas fichero fridge=',len(df.index))
# Out:
# filas fichero fridge= 36477

# %%
with open(r'.\data\ozm1\ozm_kettle_200MS.parquet', 'rb') as f:
    df = pd.read_parquet(f, engine='pyarrow')
print ('filas fichero kettle=',len(df.index))
# Out:
# filas fichero kettle= 36494

# %%
with open(r'.\data\ozm1\ozm_microvawe_200MS.parquet', 'rb') as f:
    df = pd.read_parquet(f, engine='pyarrow')
print ('filas fichero microwave=',len(df.index))
# Out:
# filas fichero microwave= 36494

# %%
with open(r'.\data\ozm1\ozm_monitor_200MS.parquet', 'rb') as f:
    df = pd.read_parquet(f, engine='pyarrow')
print ('filas fichero monitor=',len(df.index))
# Out:
# filas fichero monitor= 36494

# %%
with open(r'.\data\ozm1\ozm_oil_heater_200MS.parquet', 'rb') as f:
    df = pd.read_parquet(f, engine='pyarrow')
print ('filas fichero oil_heater=',len(df.index))
# Out:
# filas fichero oil_heater= 36494

# %%
with open(r'.\data\ozm1\ozm_oven_200MS.parquet', 'rb') as f:
    df = pd.read_parquet(f, engine='pyarrow')
print ('filas fichero oven=',len(df.index))
# Out:
# filas fichero oven= 36494

# %%
with open(r'.\data\ozm1\ozm_vacuum_cleaner_200MS.parquet', 'rb') as f:
    df = pd.read_parquet(f, engine='pyarrow')
print ('filas fichero vacuum cleaner=',len(df.index))
# Out:
# filas fichero vacuum cleaner= 36494

# %%
with open(r'.\data\ozm1\ozm_water_heater_200MS.parquet', 'rb') as f:
    df = pd.read_parquet(f, engine='pyarrow')
print ('filas fichero water_heater=',len(df.index))
# Out:
# filas fichero water_heater= 36477

# %% [markdown]
# Y veamos ahora el fichero de las agregaciones:

# %%
with open(r'.\data\ozm1\ozm_aggregation_200MS.parquet', 'rb') as f:
    df_datos_agregados = pd.read_parquet(f, engine='pyarrow')
print ('filas fichero agregation=',len(df_datos_agregados.index))
# Out:
# filas fichero agregation= 36494

# %% [markdown]
# Las primeras N filas del dataFrame se puede visualizar de la siguiente forma

# %%
N=4
df_datos_agregados.head(N)
# Out:
#      Tag  FirstTimestamp  OriginalTimestamp           Time  Voltage   Current  \
# 0  start   1678183838073      1678183868044  1678183838073  247.147  0.142013
# 1  start   1678183838073      1678183868044  1678183838273  247.202  0.143942
# 2  start   1678183838073      1678183868044  1678183838473  247.190  0.153028
# 3  start   1678183838073      1678183868044  1678183838673  247.137  0.148763
#
#    Frequency  Flag  Unbalance  Power_Factor      Phi  Active_Power  \
# 0    49.9944     0          0      0.629637  18.8298       22.0991
# 1    49.9942     0          0      0.632288  19.4552       22.4985
# 2    49.9942     0          0      0.624243  18.8179       23.6133
# 3    49.9940     0          0      0.623314  19.0161       22.9160
#
#    Reactive_Power  Apparent_Power  Current_THD  Voltage_THD  \
# 0        -7.54384       23.351248      297.623      3.70302
# 1        -7.95450       23.863322      305.911      3.71142
# 2        -8.05194       24.948382      317.283      3.71310
# 3        -7.90510       24.241202      311.150      3.65417
#
#                                      Power_Harmonics  \
# 0  [22.1221, 0.000468, 0.023443, -2.9e-05, -0.036...
# 1  [22.5188, -0.000179, 0.022105, 0.000151, -0.03...
# 2  [23.6282, -0.000551, 0.020859, 0.000143, -0.03...
# 3  [22.9371, -8.3e-05, 0.022485, 9e-05, -0.037093...
#
#                            Voltage_Harmonics_Complex  \
# 0  [[22.9884, -246.015], [-0.001805, 0.07656], [1...
# 1  [[23.6718, -246.006], [0.060496, -0.093363], [...
# 2  [[22.5654, -246.098], [-0.046821, -0.089469], ...
# 3  [[23.3384, -245.973], [-0.02625, 0.003081], [1...
#
#                            Current_Harmonics_Complex
# 0  [[0.038729, -0.086303], [0.003932, 0.006209], ...
# 1  [[0.040765, -0.087615], [0.004175, 0.004619], ...
# 2  [[0.041176, -0.092236], [0.002784, 0.004698], ...
# 3  [[0.04062, -0.089397], [0.003748, 0.005119], [...

# %% [markdown]
# Y las N últimas filas

# %%
df_datos_agregados.tail(N)
# Out:
#        Tag  FirstTimestamp  OriginalTimestamp           Time  Volt

#
#                            Voltage_Harmonics_Complex  \
# 0  [[22.9884, -246.015], [-0.001805, 0.07656], [1...
# 1  [[23.6718, -246.006], [0.060496, -0.093363], [...
# 2  [[22.5654, -246.098], [-0.046821, -0.089469], ...
# 3  [[23.3384, -245.973], [-0.02625, 0.003081], [1...
# 4  [[23.9898, -245.946], [-0.059052, -0.051255], ...
#
#                            Current_Harmonics_Complex
# 0  [[0.038729, -0.086303], [0.003932, 0.006209], ...
# 1  [[0.040765, -0.087615], [0.004175, 0.004619], ...
# 2  [[0.041176, -0.092236], [0.002784, 0.004698], ...
# 3  [[0.04062, -0.089397], [0.003748, 0.005119], [...
# 4  [[0.041584, -0.09869], [0.009022, 0.010187], [...

# %% [markdown]
# Filtramos por un valor numerico

# %%
df_datos_agregados[df_datos_agregados.Frequency >=50 ].head()
# Out:
#       Tag  FirstTimestamp  OriginalTimestamp           Time  Voltage  \
# 85  start   1678183838073      1678183868044  1678183855068  247.004
# 86  start   1678183838073      1678183868044  1678183855268  246.935
# 87  start   1678183838073      1678183868044  1678183855467  246.934
# 88  start   1678183838073      1678183868044  1678183855667  246.931
# 89  start   1678183838073      1678183868044  1678183855867  246.990
#
#      Current  Frequency  Flag  Unbalance  Power_Factor      Phi  Active_Power  \
# 85  0.138361    50.0002     0          0      0.627473  18.9997       21.4444
# 86  0.137926    50.0002     0          0      0.633768  17.7942       21.5854
# 87  0.136405    50.0006     0          0      0.628157  19.2638       21.1582
# 88  0.136742    50.0006     0          0      0.639620  17.3772       21.5973
# 89  0.139116    50.0010     0          0      0.607417  18.1723       20.8709
#
#     Reactive_Power  Apparent_Power  Current_THD  Voltage_THD  \
# 85        -7.39590       22.683934      305.425      3.62141
# 86        -6.93884       22.673305      318.530      3.65538
# 87        -7.40362       22.416152      307.983      3.63960
# 88        -6.77003       22.633501      303.415      3.65313
# 89        -6.85977       21.969356      332.727      3.63007
#
#                                       Power_Harmonics  \
# 85  [21.4796, 0.000131, 0.020758, -1.5e-05, -0.041...
# 86  [21.6195, -0.000345, 0.022297, 4e-05, -0.04397...
# 87  [21.1843, -0.000355, 0.02352, 5.5e-05, -0.0378...
# 88  [21.6333, 6.7e-05, 0.020669, 1.3e-05, -0.03906...
# 89  [20.8981, -0.00047, 0.020237, -1.8e-05, -0.035...
#
#                             Voltage_Harmonics_Complex  \
# 85  [[25.1921, -245.658], [0.050519, -0.033513], [...
# 86  [[25.5161, -245.555], [-0.025592, -0.051808], ...
# 87  [[25.5262, -245.553], [-0.065767, -0.032003], ...
# 88  [[25.42, -245.561], [0.003103, 0.012843], [1.0...
# 89  [[25.6793, -245.593], [-0.016852, -0.073092], ...
#
#                             Current_Harmonics_Complex
# 85  [[0.038666, -0.083472], [0.006279, 0.005546], ...
# 86  [[0.037007, -0.084198], [0.003462, 0.004944], ...
# 87  [[0.038701, -0.082249], [0.002857, 0.005221], ...
# 88  [[0.0363, -0.08434], [0.003837, 0.004294], [-0...
# 89  [[0.03643, -0.081283], [0.003788, 0.005562], [...

# %% [markdown]
# # Creacion de los ficheros de datos en formato csv a partir de los parquet
#
# A  continuacion vamos a hacer una serie  de manipulaciones con los datos aportados en los ficheros de datos en formato novedoso comprimido parquet.
#
# Resumidamente  estos son los pasos que vamos a seguir:
#
#
# - En primer lugar cargaremos los ficheros en un dataset
# - En segundo lugar calcularemos la potencia aparente en funcion de dos columnas ( pot real y pot reactiva)
# - En tercer lugar eliminaremos las columnas qeu no vamos a necesitar
# - Seguidamente reordenamos las columnas en el orden que necesitamos
# - Finalmente salvamos el dataset obtenido en un fichero en formato csv

# %% [markdown]
# ## Generación del fichero de datos a partir del fichero fan.csv

# %%
import pandas as pd
import numpy as np

with open(r'.\data\ozm1\ozm_fan_200MS.parquet', 'rb') as f:
    df_datos_agregados = pd.read_parquet(f, engine='pyarrow')
    

df_datos_agregados.rename(columns={'Time':'timestamp','Active_Power':'W','Reactive_Power':'VAR','Apparent_Power':'VA'} ,inplace=True)
df_datos_agregados.rename(columns={'Frequency':'f','Voltage':'VLN','Power_Factor':'PF','Current':'A' },inplace=True)



df_datos_agregados.drop (['FirstTimestamp','OriginalTimestamp','Tag'],axis = 'columns', inplace=True)
df_datos_agregados.drop (['Voltage_Harmonics_Complex','Current_Harmonics_Complex','Power_Harmonics'],axis = 'columns', inplace=True)
df_datos_agregados.drop (['Flag','Unbalance','Phi'],axis = 'columns', inplace=True)



df_datos_agregados=df_datos_agregados [['timestamp','W','VAR','VA','f','VLN','PF','A']]

print (df_datos_agregados)

df_datos_agregados.to_csv('fan.csv')
# Out:
#            timestamp        W      VAR        VA        f      VLN        PF  \
# 0      1678183838160  8.27919 -3.32329  8.921284  50.0430  246.757  0.830807
# 1      1678183838359  8.82715 -4.21068  9.780004  50.0425  246.684  0.632766
# 2      1678183838559  8.13951 -3.45906  8.844019  50.0419  245.835  0.836921
# 3      1678183838760  8.22832 -3.80827  9.066871  50.0419  247.098  0.785543
# 4      1678183838959  7.86661 -3.01599  8.424946  50.0421  246.592  0.510265
# ...              ...      ...      ...       ...      ...      ...       ...
# 36471  1678191134659  8.01664 -3.22857  8.642352  50.0204  248.214  0.807380
# 36472  1678191134859  8.18725 -3.05498  8.738644  50.0202  247.545  0.579324
# 36473  1678191135060  8.33964 -3.30322  8.970001  50.0238  248.542  0.793166
# 36474  1678191135260  7.88351 -3.29144  8.543029  50.0252  248.305  0.803086
# 36475  1678191135460  7.71389 -3.21511  8.357090  50.0244  247.884  0.802812
#
#               A
# 0      0.040385
# 1      0.056551
# 2      0.039561
# 3      0.042391
# 4      0.062519
# ...         ...
# 36471  0.040003
# 36472  0.057090
# 36473  0.042304
# 36474  0.039534
# 36475  0.038762
#
# [36476 rows x 8 columns]

# %% [markdown]
# ## Generación del fichero de datos a partir del fichero freezer.csv

# %%
import pandas as pd
import numpy as np

with open(r'.\data\ozm1\ozm_freezer_200MS.parquet', 'rb') as f:
    df_datos_agregados  = pd.read_parquet(f, engine='pyarrow')
    
df_datos_agregados.rename(columns={'Time':'timestamp','Active_Power':'W','Reactive_Power':'VAR','Apparent_Power':'VA'} ,inplace=True)
df_datos_agregados.rename(columns={'Frequency':'f','Voltage':'VLN','Power_Factor':'PF','Current':'A' },inplace=True)



df_datos_agregados.drop (['FirstTimestamp','OriginalTimestamp','Tag'],axis = 'columns', inplace=True)
df_datos_agregados.drop (['Voltage_Harmonics_Complex','Current_Harmonics_Complex','Power_Harmonics'],axis = 'columns', inplace=True)
df_datos_agregados.drop (['Flag','Unbalance','Phi'],axis = 'columns', inplace=True)



df_datos_agregados=df_datos_agregados [['timestamp','W','VAR','VA','f','VLN','PF','A']]

print (df_datos_agregados)

print (df_datos_agregados)

df_datos_agregados.to_csv('freezer.csv')
# Out:
#            timestamp        W      VAR        VA        f      VLN        PF  \
# 0      1678183838160  8.48107 -2.37765  8.808050  50.0430  246.757  0.810394
# 1      1678183838359  8.55211 -2.70065  8.968393  50.0425  246.684  0.744958
# 2      1678183838559  7.92745 -2.77020  8.397524  50.0419  245.835  0.840469
# 3      1678183838760  8.64608 -2.98154  9.145724  50.0419  247.098  0.822757
# 4      1678183838959  8.44640 -3.02546  8.971908  50.0421  246.592  0.706513
# ...              ...      ...      ...       ...      ...      ...       ...
# 36472  1678191134659  8.23880 -2.91033  8.737724  50.0204  248.214  0.833919
# 36473  1678191134859  8.67808 -3.44992  9.338684  50.0202  247.545  0.720240
# 36474  1678191135060  8.66752 -3.29412  9.272388  50.0238  248.542  0.829965
# 36475  1678191135260  9.37141 -3.39220  9.966460  50.0252  248.305  0.843649
# 36476  1678191135460  9.17099 -3.20873  9.716121  50.0244  247.884  0.850830
#
#               A
# 0      0.042412
# 1      0.046537
# 2      0.038368
# 3      0.042528
# 4      0.048481
# ...         ...
# 36472  0.039803
# 36473  0.048673
# 36474  0.042018
# 36475  0.044736
# 36476  0.043484
#
# [36477 rows x 8 columns]
#            timestamp        W      VAR        VA        f      VLN        PF  \
# 36492  1678191135191  3.53651 -2.29790  4.217496  49.9894  248.630  0.565698
# 36493  1678191135391  3.67424 -2.56106  4.478739  49.9890  248.578  0.512478
#
#               A
# 0      0.023639
# 1      0.027408
# 2      0.024979
# 3      0.026319
# 4      0.026203
# ...         ...
# 36489  0.026832
# 36490  0.026467
# 36491  0.026791
# 36492  0.025144
# 36493  0.028842
#
# [36494 rows x 8 columns]

# %% [markdown]
# ## Generación del fichero de datos a partir del fichero vacuum_cleaner.csv

# %%
import pandas as pd
import numpy as np
with open(r'.\data\ozm1\ozm_vacuum_cleaner_200MS.parquet', 'rb') as f:
    df_datos_agregados = pd.read_parquet(f, engine='pyarrow')
    


df_datos_agregados.rename(columns={'Time':'timestamp','Active_Power':'W','Reactive_Power':'VAR','Apparent_Power':'VA'} ,inplace=True)
df_datos_agregados.rename(columns={'Frequency':'f','Voltage':'VLN','Power_Factor':'PF','Current':'A' },inplace=True)



df_datos_agregados.drop (['FirstTimestamp','OriginalTimestamp','Tag'],axis = 'columns', inplace=True)
df_datos_agregados.drop (['Voltage_Harmonics_Complex','Current_Harmonics_Complex','Power_Harmonics'],axis = 'columns', inplace=True)
df_datos_agregados.drop (['Flag','Unbalance','Phi'],axis = 'columns', inplace=True)



df_datos_agregados=df_datos_agregados [['timestamp','W','VAR','VA','f','VLN','PF','A']]

print (df_datos_agregados)


#generamos el fichero de salida en formato csv
df_datos_agregados.to_csv('vacuum_cleaner.csv')
# Out:
#            timestamp        W       VAR         VA        f      VLN  \
# 0      1678183838046  7.61768 -1.124520   7.700237  49.9948  248.333
# 1      1678183838246  7.05141 -0.909240   7.109787  49.9944  248.379
# 2      1678183838446  6.82124 -1.330110   6.949708  49.9944  248.344
# 3      1678183838646  7.16882 -1.005770   7.239034  49.9942  248.319
# 4      1678183838846  9.43979 -4.054070  10.273516  49.9942  248.335
# ...              ...      ...       ...        ...      ...      ...
# 36489  1678191134589  6.66328 -1.410960   6.811032  49.9806  250.000
# 36490  1678191134789  6.21335 -0.704507   6.253158  49.9806  250.004
# 36491  1678191134989  6.24256 -1.601110   6.444622  49.9804  249.972
# 36492  1678191135189  6.19570 -1.094290   6.291590  49.9802  249.922
# 36493  1678191135389  6.96085 -1.670060   7.158392  49.9802  249.932
#
#              PF         A
# 0      0.722310  0.042468
# 1      0.709923  0.039990
# 2      0.657028  0.041805
# 3      0.579907  0.049783
# 4      0.276131  0.137661
# ...         ...       ...
# 36489  0.783094  0.034036
# 36490  0.766175  0.032438
# 36491  0.749852  0.033304
# 36492  0.731695  0.033881
# 36493  0.802358  0.034711
#
# [36494 rows x 8 columns]

# %% [markdown]
# ## Generación del fichero de datos a partir del fichero water_heater.csv

# %%
import pandas as pd
import numpy as np



with open(r'.\data\ozm1\ozm_water_heater_200MS.parquet', 'rb') as f:
    df_datos_agregados = pd.read_parquet(f, engine='pyarrow')
    

df_datos_agregados.rename(columns={'Time':'timestamp','Active_Power':'W','Reactive_Power':'VAR','Apparent_Power':'VA'} ,inplace=True)
df_datos_agregados.rename(columns={'Frequency':'f','Voltage':'VLN','Power_Factor':'PF','Current':'A' },inplace=True)



df_datos_agregados.drop (['FirstTimestamp','OriginalTimestamp','Tag'],axis = 'columns', inplace=True)
df_datos_agregados.drop (['Voltage_Harmonics_Complex','Current_Harmonics_Complex','Power_Harmonics'],axis = 'columns', inplace=True)
df_datos_agregados.drop (['Flag','Unbalance','Phi'],axis = 'columns', inplace=True)



df_datos_agregados=df_datos_agregados [['timestamp','W','VAR','VA','f','VLN','PF','A']]



print (df_datos_agregados)

df_datos_agregados.to_csv('water_heater.csv')
# Out:
#            timestamp        W      VAR         VA        f      VLN        PF  \
# 0      1678183838160  9.49962 -2.54506   9.834642  50.0430  246.757  0.878536
# 1      1678183838359  9.66515 -2.88804  10.087409  50.0425  246.684  0.875040
# 2      1678183838559  9.02983 -2.78650   9.449997  50.0419  245.835  0.861048
# 3      1678183838760  9.26818 -2.23573   9.534026  50.0419  247.098  0.619148
# 4      1678183838959  9.03674 -2.18946   9.298193  50.0421  246.592  0.766949
# ...              ...      ...      ...        ...      ...      ...       ...
# 36472  1678191134659  8.27656 -2.60421   8.676596  50.0204  248.214  0.820909
# 36473  1678191134860  8.68970 -2.51686   9.046854  50.0202  247.545  0.856448
# 36474  1678191135060  9.16284 -2.39700   9.471177  50.0238  248.542  0.869879
# 36475  1678191135260  9.38272 -2.81346   9.795460  50.0252  248.305  0.728918
# 36476  1678191135460  8.48807 -2.94635   8.984898  50.0244  247.884  0.812794
#
#               A
# 0      0.043821
# 1      0.044775
# 2      0.042659
# 3      0.060580
# 4      0.047782
# ...         ...
# 36472  0.040619
# 36473  0.040987
# 36474  0.042381
# 36475  0.051840
# 36476  0.042129
#
# [36477 rows x 8 columns]

# %% [markdown]
# ## Generación del fichero de datos a partir del fichero kettle.csv

# %%
import pandas as pd
import numpy as np


with open(r'.\data\ozm1\ozm_kettle_200MS.parquet', 'rb') as f:
    df_datos_agregados = pd.read_parquet(f, engine='pyarrow')

    

df_datos_agregados.rename(columns={'Time':'timestamp','Active_Power':'W','Reactive_Power':'VAR','Apparent_Power':'VA'} ,inplace=True)
df_datos_agregados.rename(columns={'Frequency':'f','Voltage':'VLN','Power_Factor':'PF','Current':'A' },inplace=True)



df_datos_agregados.drop (['FirstTimestamp','OriginalTimestamp','Tag'],axis = 'columns', inplace=True)
df_datos_agregados.drop (['Voltage_Harmonics_Complex','Current_Harmonics_Complex','Power_Harmonics'],axis = 'columns', inplace=True)
df_datos_agregados.drop (['Flag','Unbalance','Phi'],axis = 'columns', inplace=True)



df_datos_agregados=df_datos_agregados [['timestamp','W','VAR','VA','f','VLN','PF','A']]


print (df_datos_agregados)

df_datos_agregados.to_csv('kettle.csv')
# Out:
#            timestamp        W       VAR        VA        f      VLN        PF  \
# 0      1678183838046  9.32537 -2.464010  9.645407  49.9948  248.333  0.790670
# 1      1678183838246  9.53717 -2.514080  9.862971  49.9944  248.379  0.788887
# 2      1678183838446  9.33392 -2.788730  9.741613  49.9944  248.344  0.666008
# 3      1678183838646  9.58691 -2.651410  9.946798  49.9942  248.319  0.624579
# 4      1678183838846  8.50235 -0.585586  8.522494  49.9942  248.335  0.415885
# ...              ...      ...       ...       ...      ...      ...       ...
# 36489  1678191134589  8.39523 -1.798760  8.585764  49.9806  250.000  0.809962
# 36490  1678191134789  8.60050 -1.909200  8.809858  49.9806  250.004  0.845774
# 36491  1678191134989  8.59398 -2.029950  8.830473  49.9804  249.972  0.825125
# 36492  1678191135189  8.55765 -1.946210  8.776164  49.9802  249.922  0.846556
# 36493  1678191135389  8.91435 -1.911240  9.116929  49.9802  249.932  0.810187
#
#               A
# 0      0.047494
# 1      0.048673
# 2      0.056433
# 3      0.061813
# 4      0.082324
# ...         ...
# 36489  0.041460
# 36490  0.040674
# 36491  0.041666
# 36492  0.040448
# 36493  0.044023
#
# [36494 rows x 8 columns]

# %% [markdown]
# ## Generación del fichero de datos a partir del fichero fridge.csv

# %%
import pandas as pd
import numpy as np


with open(r'.\data\ozm1\ozm_fridge_200MS.parquet', 'rb') as f:
    df_datos_agregados = pd.read_parquet(f, engine='pyarrow')

    
df_datos_agregados.rename(columns={'Time':'timestamp','Active_Power':'W','Reactive_Power':'VAR','Apparent_Power':'VA'} ,inplace=True)
df_datos_agregados.rename(columns={'Frequency':'f','Voltage':'VLN','Power_Factor':'PF','Current':'A' },inplace=True)



df_datos_agregados.drop (['FirstTimestamp','OriginalTimestamp','Tag'],axis = 'columns', inplace=True)
df_datos_agregados.drop (['Voltage_Harmonics_Complex','Current_Harmonics_Complex','Power_Harmonics'],axis = 'columns', inplace=True)
df_datos_agregados.drop (['Flag','Unbalance','Phi'],axis = 'columns', inplace=True)



df_datos_agregados=df_datos_agregados [['timestamp','W','VAR','VA','f','VLN','PF','A']]

print (df_datos_agregados)

df_datos_agregados.to_csv('fridge.csv')
# Out:
#            timestamp        W      VAR         VA        f      VLN        PF  \
# 0      1678183838160  9.70459 -1.70343   9.852954  50.0430  246.757  0.861677
# 1      1678183838359  9.40654 -2.08848   9.635596  50.0425  246.684  0.896402
# 2      1678183838559  9.59462 -2.17803   9.838727  50.0419  245.835  0.889576
# 3      1678183838760  9.88155 -2.06080  10.094149  50.0419  247.098  0.902259
# 4      1678183838959  9.85785 -1.77212  10.015867  50.0421  246.592  0.885948
# ...              ...      ...      ...        ...      ...      ...       ...
# 36472  1678191134659  8.81806 -2.71574   9.226775  50.0204  248.214  0.859171
# 36473  1678191134859  9.44776 -2.21975   9.705022  50.0202  247.545  0.863319
# 36474  1678191135060  9.89497 -2.24108  10.145580  50.0238  248.542  0.883615
# 36475  1678191135259  9.32844 -2.12798   9.568078  50.0252  248.305  0.898416
# 36476  1678191135460  9.66039 -2.39097   9.951878  50.0244  247.884  0.898098
#
#               A
# 0      0.045642
# 1      0.042539
# 2      0.043873
# 3      0.044323
# 4      0.045123
# ...         ...
# 36472  0.041349
# 36473  0.044208
# 36474  0.045056
# 36475  0.041816
# 36476  0.043393
#
# [36477 rows x 8 columns]

# %% [markdown]
# ## Generación del fichero de datos a partir del fichero microwave.csv

# %%
import pandas as pd
import numpy as np


with open(r'C:\Users\carlo\jupyter_notebooks\ozm_datos_completos _noviembre1_ALEATORIOS\data\ozm1\ozm_microvawe_200MS.parquet', 'rb') as f:
    df_datos_agregados = pd.read_parquet(f, engine='pyarrow')

    

df_datos_agregados.rename(columns={'Time':'timestamp','Active_Power':'W','Reactive_Power':'VAR','Apparent_Power':'VA'} ,inplace=True)
df_datos_agregados.rename(columns={'Frequency':'f','Voltage':'VLN','Power_Factor':'PF','Current':'A' },inplace=True)



df_datos_agregados.drop (['FirstTimestamp','OriginalTimestamp','Tag'],axis = 'columns', inplace=True)
df_datos_agregados.drop (['Voltage_Harmonics_Complex','Current_Harmonics_Complex','Power_Harmonics'],axis = 'columns', inplace=True)
df_datos_agregados.drop (['Flag','Unbalance','Phi'],axis = 'columns', inplace=True)



df_datos_agregados=df_datos_agregados [['timestamp','W','VAR','VA','f','VLN','PF','A']]

print (df_datos_agregados)

df_datos_agregados.to_csv('microwave.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-24-b203144a875a> in <module>()
#       3
#       4
# ----> 5 with open(r'C:\Users\carlo\jupyter_notebooks\ozm_datos_completos _noviembre1_ALEATORIOS\data\ozm1\ozm_microvawe_200MS.parquet', 'rb') as f:
#       6     df_datos_agregados = pd.read_parquet(f, engine='pyarrow')
#       7
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\carlo\\jupyter_notebooks\\ozm_datos_completos _noviembre1_ALEATORIOS\\data\\ozm1\\ozm_microvawe_200MS.parquet'

# %% [markdown]
# ## Generación del fichero de datos a partir del fichero oil_heater.csv

# %%
import pandas as pd
import numpy as np


with open(r'.\data\ozm1\ozm_oil_heater_200MS.parquet', 'rb') as f:
    df_datos_agregados = pd.read_parquet(f, engine='pyarrow')

    
    
df_datos_agregados.rename(columns={'Time':'timestamp','Active_Power':'W','Reactive_Power':'VAR','Apparent_Power':'VA'} ,inplace=True)
df_datos_agregados.rename(columns={'Frequency':'f','Voltage':'VLN','Power_Factor':'PF','Current':'A' },inplace=True)



df_datos_agregados.drop (['FirstTimestamp','OriginalTimestamp','Tag'],axis = 'columns', inplace=True)
df_datos_agregados.drop (['Voltage_Harmonics_Complex','Current_Harmonics_Complex','Power_Harmonics'],axis = 'columns', inplace=True)
df_datos_agregados.drop (['Flag','Unbalance','Phi'],axis = 'columns', inplace=True)



df_datos_agregados=df_datos_agregados [['timestamp','W','VAR','VA','f','VLN','PF','A']]

print (df_datos_agregados)


df_datos_agregados.to_csv('oil_heater.csv')

# %% [markdown]
# ## Generación del fichero de datos a partir del fichero oven.csv

# %%
import pandas as pd
import numpy as np


with open(r'.\data\ozm1\ozm_oven_200MS.parquet', 'rb') as f:
    df_datos_agregados = pd.read_parquet(f, engine='pyarrow')

    
df_datos_agregados.rename(columns={'Time':'timestamp','Active_Power':'W','Reactive_Power':'VAR','Apparent_Power':'VA'} ,inplace=True)
df_datos_agregados.rename(columns={'Frequency':'f','Voltage':'VLN','Power_Factor':'PF','Current':'A' },inplace=True)



df_datos_agregados.drop (['FirstTimestamp','OriginalTimestamp','Tag'],axis = 'columns', inplace=True)
df_datos_agregados.drop (['Voltage_Harmonics_Complex','Current_Harmonics_Complex','Power_Harmonics'],axis = 'columns', inplace=True)
df_datos_agregados.drop (['Flag','Unbalance','Phi'],axis = 'columns', inplace=True)



df_datos_agregados=df_datos_agregados [['timestamp','W','VAR','VA','f','VLN','PF','A']]

print (df_datos_agregados)

df_datos_agregados.to_csv('oven.csv')

# %% [markdown]
# ## Generación del fichero de datos a partir del fichero aggregation.h5

# %%
import pandas as pd
import numpy as np


with open(r'.\data\ozm1\ozm_aggregation_200MS.parquet', 'rb') as f:
    df_datos_agregados = pd.read_parquet(f, engine='pyarrow')

df_datos_agregados.rename(columns={'Time':'timestamp','Active_Power':'W','Reactive_Power':'VAR','Apparent_Power':'VA'} ,inplace=True)
df_datos_agregados.rename(columns={'Frequency':'f','Voltage':'VLN','Power_Factor':'PF','Current':'A' },inplace=True)



df_datos_agregados.drop (['FirstTimestamp','OriginalTimestamp','Tag'],axis = 'columns', inplace=True)
df_datos_agregados.drop (['Voltage_Harmonics_Complex','Current_Harmonics_Complex','Power_Harmonics'],axis = 'columns', inplace=True)
df_datos_agregados.drop (['Flag','Unbalance','Phi'],axis = 'columns', inplace=True)



df_datos_agregados=df_datos_agregados [['timestamp','W','VAR','VA','f','VLN','PF','A']]

print (df_datos_agregados)

df_datos_agregados.to_csv('aggregation.csv')

# %% [markdown]
# ## Eliminacion de los indices de los dataset

# %% [markdown]
# En los ficheros de datos no nos es util el valor autoincremental  al no ser una variable electrica . Recordar que este valor es  usado como indice del dataset.
#
# Para ello ,usaremos como indice el valor del timestamp, dado que este valor es biunivoco.
#
# Vamos a reconstruir los ficheros csv eliminando pues ese campo.

# %% [markdown]
# ### Fichero de datos contador principal

# %% [markdown]
# Empezemos eliminando el indice en el fichero de agregaciones ( es decir el fichero del contador global)

# %%
import pandas as pd
import numpy as np
with open(r'.\data\ozm1\ozm_aggregation_200MS.parquet', 'rb') as f:
    df_datos_agregados = pd.read_parquet(f, engine='pyarrow')
    
df_datos_agregados.rename(columns={'Time':'timestamp','Active_Power':'W','Reactive_Power':'VAR','Apparent_Power':'VA'} ,inplace=True)
df_datos_agregados.rename(columns={'Frequency':'f','Voltage':'VLN','Power_Factor':'PF','Current':'A' },inplace=True)



df_datos_agregados.drop (['FirstTimestamp','OriginalTimestamp','Tag'],axis = 'columns', inplace=True)
df_datos_agregados.drop (['Voltage_Harmonics_Complex','Current_Harmonics_Complex','Power_Harmonics'],axis = 'columns', inplace=True)
df_datos_agregados.drop (['Flag','Unbalance','Phi'],axis = 'columns', inplace=True)



df_datos_agregados=df_datos_agregados [['timestamp','W','VAR','VA','f','VLN','PF','A']]



df_reset=df_datos_agregados.set_index('timestamp')


print (df_reset)

df_reset.to_csv('aggregation.csv')
# Out:
#                      W      VAR         VA        f      VLN        PF  \
# timestamp
# 1678183838073  22.0991 -7.54384  23.351248  49.9944  247.147  0.629637
# 1678183838273  22.4985 -7.95450  23.863322  49.9942  247.202  0.632288
# 1678183838473  23.6133 -8.05194  24.948382  49.9942  247.190  0.624243
# 1678183838673  22.9160 -7.90510  24.241202  49.9940  247.137  0.623314
# 1678183838873  25.2503 -7.85989  26.445364  49.9940  247.172  0.574146
# ...                ...      ...        ...      ...      ...       ...
# 1678191134591  17.2421 -6.49109  18.423425  49.9896  248.690  0.553813
# 1678191134791  18.2619 -6.86620  19.510054  49.9896  248.716  0.554462
# 1678191134991  17.6728 -6.27814  18.754765  49.9894  248.676  0.549108
# 1678191135191  17.7137 -6.64853  18.920320  49.9894  248.630  0.555321
# 1678191135391  17.4481 -6.69050  18.686859  49.9890  248.578  0.549747
#
#                       A
# timestamp
# 1678183838073  0.142013
# 1678183838273  0.143942
# 1678183838473  0.153028
# 1678183838673  0.148763
# 1678183838873  0.177928
# ...                 ...
# 1678191134591  0.125190
# 1678191134791  0.132425
# 1678191134991  0.129423
# 1678191135191  0.128296
# 1678191135391  0.127680
#
# [36494 rows x 7 columns]

# %% [markdown]
# ### PROCESAMIENTO DE LOS FICHEROS

# %% [markdown]
# ### Fichero del contador principal (1)

# %%
import pandas as pd
import numpy as np

with open(r'.\data\ozm1\ozm_aggregation_200MS.parquet', 'rb') as f:
    df_datos_agregados = pd.read_parquet(f, engine='pyarrow')
    
df_datos_agregados.rename(columns={'Time':'timestamp','Active_Power':'W','Reactive_Power':'VAR','Apparent_Power':'VA'} ,inplace=True)
df_datos_agregados.rename(columns={'Frequency':'f','Voltage':'VLN','Power_Factor':'PF','Current':'A' },inplace=True)



df_datos_agregados.drop (['FirstTimestamp','OriginalTimestamp','Tag'],axis = 'columns', inplace=True)
df_datos_agregados.drop (['Voltage_Harmonics_Complex','Current_Harmonics_Complex','Power_Harmonics'],axis = 'columns', inplace=True)
df_datos_agregados.drop (['Flag','Unbalance','Phi'],axis = 'columns', inplace=True)



df_datos_agregados=df_datos_agregados [['timestamp','W','VAR','VA','f','VLN','PF','A']]


df_reset=df_datos_agregados.set_index('timestamp')

print (df_reset)

df_reset.to_csv('aggregation.csv')
# Out:
#                      W      VAR         VA        f      VLN        PF  \
# timestamp
# 1678183838073  22.0991 -7.54384  23.351248  49.9944  247.147  0.629637
# 1678183838273  22.4985 -7.95450  23.863322  49.9942  247.202  0.632288
# 1678183838473  23.6133 -8.05194  24.948382  49.9942  247.190  0.624243
# 1678183838673  22.9160 -7.90510  24.241202  49.9940  247.137  0.623314
# 1678183838873  25.2503 -7.85989  26.445364  49.9940  247.172  0.574146
# ...                ...      ...        ...      ...      ...       ...
# 1678191134591  17.2421 -6.49109  18.423425  49.9896  248.690  0.553813
# 1678191134791  18.2619 -6.86620  19.510054  49.9896  248.716  0.554462
# 1678191134991  17.6728 -6.27814  18.754765  49.9894  248.676  0.549108
# 1678191135191  17.7137 -6.64853  18.920320  49.9894  248.630  0.555321
# 1678191135391  17.4481 -6.69050  18.686859  49.9890  248.578  0.549747
#
#                       A
# timestamp
# 1678183838073  0.142013
# 1678183838273  0.143942
# 1678183838473  0.153028
# 1678183838673  0.148763
# 1678183838873  0.177928
# ...                 ...
# 1678191134591  0.125190
# 1678191134791  0.132425
# 1678191134991  0.129423
# 1678191135191  0.128296
# 1678191135391  0.127680
#
# [36494 rows x 7 columns]

# %% [markdown]
# ### Fichero de datos numero 9 (fan)

# %%
import pandas as pd
import numpy as np


with open(r'.\data\ozm1\ozm_fan_200MS.parquet', 'rb') as f:
    df_datos_agregados = pd.read_parquet(f, engine='pyarrow')
    
    
df_datos_agregados.rename(columns={'Time':'timestamp','Active_Power':'W','Reactive_Power':'VAR','Apparent_Power':'VA'} ,inplace=True)
df_datos_agregados.rename(columns={'Frequency':'f','Voltage':'VLN','Power_Factor':'PF','Current':'A' },inplace=True)



df_datos_agregados.drop (['FirstTimestamp','OriginalTimestamp','Tag'],axis = 'columns', inplace=True)
df_datos_agregados.drop (['Voltage_Harmonics_Complex','Current_Harmonics_Complex','Power_Harmonics'],axis = 'columns', inplace=True)
df_datos_agregados.drop (['Flag','Unbalance','Phi'],axis = 'columns', inplace=True)



df_datos_agregados=df_datos_agregados [['timestamp','W','VAR','VA','f','VLN','PF','A']]


df_reset=df_datos_agregados.set_index('timestamp')

print (df_reset)

df_reset.to_csv('fan.csv')
# Out:
#                      W      VAR        VA        f      VLN        PF  \
# timestamp
# 1678183838160  8.27919 -3.32329  8.921284  50.0430  246.757  0.830807
# 1678183838359  8.82715 -4.21068  9.780004  50.0425  246.684  0.632766
# 1678183838559  8.13951 -3.45906  8.844019  50.0419  245.835  0.836921
# 1678183838760  8.22832 -3.80827  9.066871  50.0419  247.098  0.785543
# 1678183838959  7.86661 -3.01599  8.424946  50.0421  246.592  0.510265
# ...                ...      ...       ...      ...      ...       ...
# 1678191134659  8.01664 -3.22857  8.642352  50.0204  248.214  0.807380
# 1678191134859  8.18725 -3.05498  8.738644  50.0202  247.545  0.579324
# 1678191135060  8.33964 -3.30322  8.970001  50.0238  248.542  0.793166
# 1678191135260  7.88351 -3.29144  8.543029  50.0252  248.305  0.803086
# 1678191135460  7.71389 -3.21511  8.357090  50.0244  247.884  0.802812
#
#                       A
# timestamp
# 1678183838160  0.040385
# 1678183838359  0.056551
# 1678183838559  0.039561
# 1678183838760  0.042391
# 1678183838959  0.062519
# ...                 ...
# 1678191134659  0.040003
# 1678191134859  0.057090
# 1678191135060  0.042304
# 1678191135260  0.039534
# 1678191135460  0.038762
#
# [36476 rows x 7 columns]

# %% [markdown]
# ### Fichero de datos freezer ( contador nº11)

# %%
import pandas as pd
import numpy as np
with open(r'.\data\ozm1\ozm_freezer_200MS.parquet', 'rb') as f:
    df_datos_agregados = pd.read_parquet(f, engine='pyarrow')
    
    
df_datos_agregados.rename(columns={'Time':'timestamp','Active_Power':'W','Reactive_Power':'VAR','Apparent_Power':'VA'} ,inplace=True)
df_datos_agregados.rename(columns={'Frequency':'f','Voltage':'VLN','Power_Factor':'PF','Current':'A' },inplace=True)



df_datos_agregados.drop (['FirstTimestamp','OriginalTimestamp','Tag'],axis = 'columns', inplace=True)
df_datos_agregados.drop (['Voltage_Harmonics_Complex','Current_Harmonics_Complex','Power_Harmonics'],axis = 'columns', inplace=True)
df_datos_agregados.drop (['Flag','Unbalance','Phi'],axis = 'columns', inplace=True)



df_datos_agregados=df_datos_agregados [['timestamp','W','VAR','VA','f','VLN','PF','A']]


df_reset=df_datos_agregados.set_index('timestamp')
print (df_reset)

df_reset.to_csv('freezer.csv')
# Out:
#                      W      VAR        VA        f      VLN        PF  \
# timestamp
# 1678183838160  8.48107 -2.37765  8.808050  50.0430  246.757  0.810394
# 1678183838359  8.55211 -2.70065  8.968393  50.0425  246.684  0.744958
# 1678183838559  7.92745 -2.77020  8.397524  50.0419  245.835  0.840469
# 1678183838760  8.64608 -2.98154  9.145724  50.0419  247.098  0.822757
# 1678183838959  8.44640 -3.02546  8.971908  50.0421  246.592  0.706513
# ...                ...      ...       ...      ...      ...       ...
# 1678191134659  8.23880 -2.91033  8.737724  50.0204  248.214  0.833919
# 1678191134859  8.67808 -3.44992  9.338684  50.0202  247.545  0.720240
# 1678191135060  8.66752 -3.29412  9.272388  50.0238  248.542  0.829965
# 1678191135260  9.37141 -3.39220  9.966460  50.0252  248.305  0.843649
# 1678191135460  9.17099 -3.20873  9.716121  50.0244  247.884  0.850830
#
#                       A
# timestamp
# 1678183838160  0.042412
# 1678183838359  0.046537
# 1678183838559  0.038368
# 1678183838760  0.042528
# 1678183838959  0.048481
# ...                 ...
# 1678191134659  0.039803
# 1678191134859  0.048673
# 1678191135060  0.042018
# 1678191135260  0.044736
# 1678191135460  0.043484
#
# [36477 rows x 7 columns]

# %% [markdown]
# ### Fichero de datos monitor o television ( contador nº4)

# %%
import pandas as pd
import numpy as np

with open(r'.\data\ozm1\ozm_monitor_200MS.parquet', 'rb') as f:
    df_datos_agregados = pd.read_parquet(f, engine='pyarrow')
    
    
df_datos_agregados.rename(columns={'Time':'timestamp','Active_Power':'W','Reactive_Power':'VAR','Apparent_Power':'VA'} ,inplace=True)
df_datos_agregados.rename(columns={'Frequency':'f','Voltage':'VLN','Power_Factor':'PF','Current':'A' },inplace=True)



df_datos_agregados.drop (['FirstTimestamp','OriginalTimestamp','Tag'],axis = 'columns', inplace=True)
df_datos_agregados.drop (['Voltage_Harmonics_Complex','Current_Harmonics_Complex','Power_Harmonics'],axis = 'columns', inplace=True)
df_datos_agregados.drop (['Flag','Unbalance','Phi'],axis = 'columns', inplace=True)



df_datos_agregados=df_datos_agregados [['timestamp','W','VAR','VA','f','VLN','PF','A']]


df_reset=df_datos_agregados.set_index('timestamp')
print (df_reset)

df_reset.to_csv('monitor.csv')
# Out:
#                      W      VAR        VA        f      VLN        PF  \
# timestamp
# 1678183838073  3.04758 -1.67218  3.476191  49.9944  247.147  0.521644
# 1678183838273  3.67423 -1.56021  3.991771  49.9942  247.202  0.542295
# 1678183838473  3.28805 -1.85104  3.773276  49.9942  247.190  0.532526
# 1678183838674  3.12649 -1.73031  3.573362  49.9940  247.137  0.480678
# 1678183838873  3.83996 -2.00342  4.331167  49.9940  247.172  0.592902
# ...                ...      ...       ...      ...      ...       ...
# 1678191134591  3.70550 -1.76192  4.103058  49.9896  248.690  0.555304
# 1678191134791  3.67628 -2.30640  4.339868  49.9896  248.716  0.558470
# 1678191134991  3.43264 -2.05542  4.000969  49.9894  248.676  0.515244
# 1678191135191  3.53651 -2.29790  4.217496  49.9894  248.630  0.565698
# 1678191135391  3.67424 -2.56106  4.478739  49.9890  248.578  0.512478
#
#                       A
# timestamp
# 1678183838073  0.023639
# 1678183838273  0.027408
# 1678183838473  0.024979
# 1678183838674  0.026319
# 1678183838873  0.026203
# ...                 ...
# 1678191134591  0.026832
# 1678191134791  0.026467
# 1678191134991  0.026791
# 1678191135191  0.025144
# 1678191135391  0.028842
#
# [36494 rows x 7 columns]

# %% [markdown]
# ### Fichero de datos vacuum cleaner ( contador nº6)

# %%
import pandas as pd
import numpy as np
with open(r'.\data\ozm1\ozm_vacuum_cleaner_200MS.parquet', 'rb') as f:
    df_datos_agregados = pd.read_parquet(f, engine='pyarrow')
    
    
df_datos_agregados.rename(columns={'Time':'timestamp','Active_Power':'W','Reactive_Power':'VAR','Apparent_Power':'VA'} ,inplace=True)
df_datos_agregados.rename(columns={'Frequency':'f','Voltage':'VLN','Power_Factor':'PF','Current':'A' },inplace=True)



df_datos_agregados.drop (['FirstTimestamp','OriginalTimestamp','Tag'],axis = 'columns', inplace=True)
df_datos_agregados.drop (['Voltage_Harmonics_Complex','Current_Harmonics_Complex','Power_Harmonics'],axis = 'columns', inplace=True)
df_datos_agregados.drop (['Flag','Unbalance','Phi'],axis = 'columns', inplace=True)



df_datos_agregados=df_datos_agregados [['timestamp','W','VAR','VA','f','VLN','PF','A']]

df_reset=df_datos_agregados.set_index('timestamp')

#pintamos el resultado
print (df_reset)
#generamos el fichero de salida en formato csv
df_reset.to_csv('vacuum_cleaner.csv')
# Out:
#                      W       VAR         VA        f      VLN        PF  \
# timestamp
# 1678183838046  7.61768 -1.124520   7.700237  49.9948  248.333  0.722310
# 1678183838246  7.05141 -0.909240   7.109787  49.9944  248.379  0.709923
# 1678183838446  6.82124 -1.330110   6.949708  49.9944  248.344  0.657028
# 1678183838646  7.16882 -1.005770   7.239034  49.9942  248.319  0.579907
# 1678183838846  9.43979 -4.054070  10.273516  49.9942  248.335  0.276131
# ...                ...       ...        ...      ...      ...       ...
# 1678191134589  6.66328 -1.410960   6.811032  49.9806  250.000  0.783094
# 1678191134789  6.21335 -0.704507   6.253158  49.9806  250.004  0.766175
# 1678191134989  6.24256 -1.601110   6.444622  49.9804  249.972  0.749852
# 1678191135189  6.19570 -1.094290   6.291590  49.9802  249.922  0.731695
# 1678191135389  6.96085 -1.670060   7.158392  49.9802  249.932  0.802358
#
#                       A
# timestamp
# 1678183838046  0.042468
# 1678183838246  0.039990
# 1678183838446  0.041805
# 1678183838646  0.049783
# 1678183838846  0.137661
# ...                 ...
# 1678191134589  0.034036
# 1678191134789  0.032438
# 1678191134989  0.033304
# 1678191135189  0.033881
# 1678191135389  0.034711
#
# [36494 rows x 7 columns]

# %% [markdown]
# ### Fichero de datos water heater ( contador nº 8)

# %%
import pandas as pd
import numpy as np
with open(r'.\data\ozm1\ozm_water_heater_200MS.parquet', 'rb') as f:
    df_datos_agregados = pd.read_parquet(f, engine='pyarrow')
    
    
df_datos_agregados.rename(columns={'Time':'timestamp','Active_Power':'W','Reactive_Power':'VAR','Apparent_Power':'VA'} ,inplace=True)
df_datos_agregados.rename(columns={'Frequency':'f','Voltage':'VLN','Power_Factor':'PF','Current':'A' },inplace=True)



df_datos_agregados.drop (['FirstTimestamp','OriginalTimestamp','Tag'],axis = 'columns', inplace=True)
df_datos_agregados.drop (['Voltage_Harmonics_Complex','Current_Harmonics_Complex','Power_Harmonics'],axis = 'columns', inplace=True)
df_datos_agregados.drop (['Flag','Unbalance','Phi'],axis = 'columns', inplace=True)



df_datos_agregados=df_datos_agregados [['timestamp','W','VAR','VA','f','VLN','PF','A']]
  

df_reset=df_datos_agregados.set_index('timestamp')

#pintamos el resultado
print (df_reset)
#generamos el fichero de salida en formato csv
df_reset.to_csv('water_heater.csv')
# Out:
#                      W      VAR         VA        f      VLN        PF  \
# timestamp
# 1678183838160  9.49962 -2.54506   9.834642  50.0430  246.757  0.878536
# 1678183838359  9.66515 -2.88804  10.087409  50.0425  246.684  0.875040
# 1678183838559  9.02983 -2.78650   9.449997  50.0419  245.835  0.861048
# 1678183838760  9.26818 -2.23573   9.534026  50.0419  247.098  0.619148
# 1678183838959  9.03674 -2.18946   9.298193  50.0421  246.592  0.766949
# ...                ...      ...        ...      ...      ...       ...
# 1678191134659  8.27656 -2.60421   8.676596  50.0204  248.214  0.820909
# 1678191134860  8.68970 -2.51686   9.046854  50.0202  247.545  0.856448
# 1678191135060  9.16284 -2.39700   9.471177  50.0238  248.542  0.869879
# 1678191135260  9.38272 -2.81346   9.795460  50.0252  248.305  0.728918
# 1678191135460  8.48807 -2.94635   8.984898  50.0244  247.884  0.812794
#
#                       A
# timestamp
# 1678183838160  0.043821
# 1678183838359  0.044775
# 1678183838559  0.042659
# 1678183838760  0.060580
# 1678183838959  0.047782
# ...                 ...
# 1678191134659  0.040619
# 1678191134860  0.040987
# 1678191135060  0.042381
# 1678191135260  0.051840
# 1678191135460  0.042129
#
# [36477 rows x 7 columns]

# %% [markdown]
# ### Fichero de datos fridge ( contador nº 10)

# %%
import pandas as pd
import numpy as np
with open(r'.\data\ozm1\ozm_fridge_200MS.parquet', 'rb') as f:
    df_datos_agregados = pd.read_parquet(f, engine='pyarrow')
    
    
    
df_datos_agregados.rename(columns={'Time':'timestamp','Active_Power':'W','Reactive_Power':'VAR','Apparent_Power':'VA'} ,inplace=True)
df_datos_agregados.rename(columns={'Frequency':'f','Voltage':'VLN','Power_Factor':'PF','Current':'A' },inplace=True)



df_datos_agregados.drop (['FirstTimestamp','OriginalTimestamp','Tag'],axis = 'columns', inplace=True)
df_datos_agregados.drop (['Voltage_Harmonics_Complex','Current_Harmonics_Complex','Power_Harmonics'],axis = 'columns', inplace=True)
df_datos_agregados.drop (['Flag','Unbalance','Phi'],axis = 'columns', inplace=True)



df_datos_agregados=df_datos_agregados [['timestamp','W','VAR','VA','f','VLN','PF','A']]

df_reset=df_datos_agregados.set_index('timestamp')

#pintamos el resultado
print (df_reset)
#generamos el fichero de salida en formato csv
df_reset.to_csv('fridge.csv')
# Out:
#                      W      VAR         VA        f      VLN        PF  \
# timestamp
# 1678183838160  9.70459 -1.70343   9.852954  50.0430  246.757  0.861677
# 1678183838359  9.40654 -2.08848   9.635596  50.0425  246.684  0.896402
# 1678183838559  9.59462 -2.17803   9.838727  50.0419  245.835  0.889576
# 1678183838760  9.88155 -2.06080  10.094149  50.0419  247.098  0.902259
# 1678183838959  9.85785 -1.77212  10.015867  50.0421  246.592  0.885948
# ...                ...      ...        ...      ...      ...       ...
# 1678191134659  8.81806 -2.71574   9.226775  50.0204  248.214  0.859171
# 1678191134859  9.44776 -2.21975   9.705022  50.0202  247.545  0.863319
# 1678191135060  9.89497 -2.24108  10.145580  50.0238  248.542  0.883615
# 1678191135259  9.32844 -2.12798   9.568078  50.0252  248.305  0.898416
# 1678191135460  9.66039 -2.39097   9.951878  50.0244  247.884  0.898098
#
#                       A
# timestamp
# 1678183838160  0.045642
# 1678183838359  0.042539
# 1678183838559  0.043873
# 1678183838760  0.044323
# 1678183838959  0.045123
# ...                 ...
# 1678191134659  0.041349
# 1678191134859  0.044208
# 1678191135060  0.045056
# 1678191135259  0.041816
# 1678191135460  0.043393
#
# [36477 rows x 7 columns]

# %% [markdown]
# ### Fichero de datos kettle ( contador nº 5)

# %%
import pandas as pd
import numpy as np
with open(r'.\data\ozm1\ozm_kettle_200MS.parquet', 'rb') as f:
    df_datos_agregados = pd.read_parquet(f, engine='pyarrow')
    
    
df_datos_agregados.rename(columns={'Time':'timestamp','Active_Power':'W','Reactive_Power':'VAR','Apparent_Power':'VA'} ,inplace=True)
df_datos_agregados.rename(columns={'Frequency':'f','Voltage':'VLN','Power_Factor':'PF','Current':'A' },inplace=True)



df_datos_agregados.drop (['FirstTimestamp','OriginalTimestamp','Tag'],axis = 'columns', inplace=True)
df_datos_agregados.drop (['Voltage_Harmonics_Complex','Current_Harmonics_Complex','Power_Harmonics'],axis = 'columns', inplace=True)
df_datos_agregados.drop (['Flag','Unbalance','Phi'],axis = 'columns', inplace=True)



df_datos_agregados=df_datos_agregados [['timestamp','W','VAR','VA','f','VLN','PF','A']]

df_reset=df_datos_agregados.set_index('timestamp')

#pintamos el resultado
print (df_reset)
#generamos el fichero de salida en formato csv
df_reset.to_csv('kettle.csv')
# Out:
#                      W       VAR        VA        f      VLN        PF  \
# timestamp
# 1678183838046  9.32537 -2.464010  9.645407  49.9948  248.333  0.790670
# 1678183838246  9.53717 -2.514080  9.862971  49.9944  248.379  0.788887
# 1678183838446  9.33392 -2.788730  9.741613  49.9944  248.344  0.666008
# 1678183838646  9.58691 -2.651410  9.946798  49.9942  248.319  0.624579
# 1678191135391  8.76016 -3.49872   9.433000  49.9890  248.578  0.786364
#
#                       A
# timestamp
# 1678183838073  0.044579
# 1678183838273  0.045681
# 1678183838473  0.044431
# 1678183838673  0.045889
# 1678183838873  0.045625
# ...                 ...
# 1678191134591  0.043273
# 1678191134791  0.044322
# 1678191134991  0.042563
# 1678191135191  0.044902
# 1678191135391  0.044815
#
# [36494 rows x 7 columns]

# %% [markdown]
# ### Fichero de datos oven ( contador nº 2)

# %%
import pandas as pd
import numpy as np


with open(r'.\data\ozm1\ozm_oven_200MS.parquet', 'rb') as f:
    df_datos_agregados = pd.read_parquet(f, engine='pyarrow')

    
df_datos_agregados.rename(columns={'Time':'timestamp','Active_Power':'W','Reactive_Power':'VAR','Apparent_Power':'VA'} ,inplace=True)
df_datos_agregados.rename(columns={'Frequency':'f','Voltage':'VLN','Power_Factor':'PF','Current':'A' },inplace=True)



df_datos_agregados.drop (['FirstTimestamp','OriginalTimestamp','Tag'],axis = 'columns', inplace=True)
df_datos_agregados.drop (['Voltage_Harmonics_Complex','Current_Harmonics_Complex','Power_Harmonics'],axis = 'columns', inplace=True)
df_datos_agregados.drop (['Flag','Unbalance','Phi'],axis = 'columns', inplace=True)



df_datos_agregados=df_datos_agregados [['timestamp','W','VAR','VA','f','VLN','PF','A']]

df_reset=df_datos_agregados.set_index('timestamp')

#pintamos el resultado
print (df_reset)
#generamos el fichero de salida en formato csv
df_reset.to_csv('oven.csv')
# Out:
#                      W       VAR        VA        f      VLN        PF  \
# timestamp
# 1678183838046  9.12492 -2.095970  9.362543  49.9948  248.333  0.787681
# 1678183838246  8.82567 -1.826750  9.012738  49.9944  248.379  0.762569
# 1678183838446  8.01402 -1.929480  8.243020  49.9944  248.344  0.682069
# 1678183838646  8.23003 -2.050490  8.481622  49.9942  248.319  0.690446
# 1678183838846  8.84426 -0.456998  8.856055  49.9942  248.335  0.506523
# ...                ...       ...       ...      ...      ...       ...
# 1678191134589  9.01243 -2.208270  9.279032  49.9806  250.000  0.798907
# 1678191134789  8.36301 -1.880470  8.571823  49.9806  250.004  0.804157
# 1678191134989  8.97219 -1.636350  9.120190  49.9804  249.972  0.824937
# 1678191135189  7.56718 -1.881630  7.797612  49.9802  249.922  0.801957
# 1678191135389  8.24864 -1.504850  8.384791  49.9802  249.932  0.804221
#
#                       A
# timestamp
# 1678183838046  0.046649
# 1678183838246  0.046597
# 1678183838446  0.047312
# 1678183838646  0.048002
# 1678183838846  0.070311
# ...                 ...
# 1678191134589  0.045124
# 1678191134789  0.041598
# 1678191134989  0.043510
# 1678191135189  0.037755
# 1678191135389  0.041038
#
# [36494 rows x 7 columns]

# %% [markdown]
# ## Analisis fechas

# %%
import pandas as pd

with open(r'.\data\ozm1\ozm_aggregation_200MS.parquet', 'rb') as f:
    df_datos_agregados = pd.read_parquet(f, engine='pyarrow')

print ('filas fichero aggregation.hdf5=',len(df_datos_agregados.index))
# Out:
# filas fichero aggregation.hdf5= 36494

# %%
N=1
df_datos_agregados.head(N)
# Out:
#      Tag  FirstTimestamp  OriginalTimestamp           Time  Voltage   Current  \
# 0  start   1678183838073      1678183868044  1678183838073  247.147  0.142013
#
#    Frequency  Flag  Unbalance  Power_Factor      Phi  Active_Power  \
# 0    49.9944     0          0      0.629637  18.8298       22.0991
#
#    Reactive_Power  Apparent_Power  Current_THD  Voltage_THD  \
# 0        -7.54384       23.351248      297.623      3.70302
#
#                                      Power_Harmonics  \
# 0  [22.1221, 0.000468, 0.023443, -2.9e-05, -0.036...
#
#                            Voltage_Harmonics_Complex  \
# 0  [[22.9884, -246.015], [-0.001805, 0.07656], [1...
#
#                            Current_Harmonics_Complex
# 0  [[0.038729, -0.086303], [0.003932, 0.006209], ...

# %%
FirstTimestamp=df_datos_agregados.iat[0,1]

# %%
OriginalTimestamp=df_datos_agregados.iat[0,2]

# %%
Time=df_datos_agregados.iat[0,3]

# %%
import pandas as pd
import numpy as np
import datetime
df=pd.DataFrame()

i=[FirstTimestamp,OriginalTimestamp,Time]
df['date']=pd.Series(i)
df['date']=df['date'].apply(lambda d: datetime.datetime.fromtimestamp(int(d)/1000).strftime('%Y-%m-%d %H:%M:%S'))

df
# Out:
#                   date
# 0  2023-03-07 11:10:38
# 1  2023-03-07 11:11:08
# 2  2023-03-07 11:10:38

# %%
df_datos_agregados.tail(N)
# Out:
#        Tag  FirstTimestamp  OriginalTimestamp           Time  Voltage  \
# 36493  end   1678191104593      1678191135486  1678191135391  248.578
#
#        Current  Frequency  Flag  Unbalance  Power_Factor      Phi  \
# 36493  0.12768     49.989     0          0      0.549747  21.0327
#
#        Active_Power  Reactive_Power  Apparent_Power  Current_THD  Voltage_THD  \
# 36493       17.4481         -6.6905       18.686859      441.336      4.25438
#
#                                          Power_Harmonics  \
# 36493  [17.3997, 0.000256, 0.036514, -0.000401, 0.031...
#
#                                Voltage_Harmonics_Complex  \
# 36493  [[21.4755, -247.557], [-0.052345, 0.076959], [...
#
#                                Current_Harmonics_Complex
# 36493  [[0.032876, -0.067433], [0.003476, 0.005692], ...

# %%
FirstTimestamp1=df_datos_agregados.iat[36493,1]

# %%
OriginalTimestamp1=df_datos_agregados.iat[36493,2]

# %%
Time1 =df_datos_agregados.iat[36493,3]

# %%
import pandas as pd
import numpy as np
import datetime
df=pd.DataFrame()

i=[FirstTimestamp1,OriginalTimestamp1,Time1]
df['date']=pd.Series(i)
df['date']=df['date'].apply(lambda d: datetime.datetime.fromtimestamp(int(d)/1000).strftime('%Y-%m-%d %H:%M:%S'))

df
# Out:
#                   date
# 0  2023-03-07 13:11:44
# 1  2023-03-07 13:12:15
# 2  2023-03-07 13:12:15

# %% [markdown]
# ## Copia de los ficheros procesados a la ruta de generacion del DS

# %%
import re
#copia el contenido de un fichero en otro
with open('aggregation.csv','r') as firstfile, open('./data/ozm1/electricity/1.csv','a') as secondfile: 
    
    for line in firstfile: 
      #  print (line)
        secondfile.write(line)

# %%
import re
#copia el contenido de un fichero en otro
with open('water_heater.csv','r') as firstfile, open('./data/ozm1/electricity/8.csv','a') as secondfile: 
    
    for line in firstfile: 
      #  print (line2)
        secondfile.write(line)

# %%
import re
#copia el contenido de un fichero en otro
with open('fan.csv','r') as firstfile, open('./data/ozm1/electricity/9.csv','a') as secondfile: 
    
    for line in firstfile: 
       #  print (line)
        secondfile.write(line)

# %%
import re
#copia el contenido de un fichero en otro
with open('freezer.csv','r') as firstfile, open('./data/ozm1/electricity/11.csv','a') as secondfile: 
    
    for line in firstfile: 
     
      #  print (line2)
        secondfile.write(line)

# %%
import re
#copia el contenido de un fichero en otro
with open('monitor.csv','r') as firstfile, open('./data/ozm1/electricity/4.csv','a') as secondfile: 
    
    for line in firstfile: 
      #  print (line2)
        secondfile.write(line)

# %%
import re
#copia el contenido de un fichero en otro
with open('vacuum_cleaner.csv','r') as firstfile, open('./data/ozm1/electricity/6.csv','a') as secondfile: 
    
    for line in firstfile: 
         #  print (line2)
        secondfile.write(line)

# %%
import re
#copia el contenido de un fichero en otro
with open('kettle.csv','r') as firstfile, open('./data/ozm1/electricity/5.csv','a') as secondfile: 
    
    for line in firstfile: 
     
      #  print (line2)
        secondfile.write(line)

# %%
import re
#copia el contenido de un fichero en otro
with open('fridge.csv','r') as firstfile, open('./data/ozm1/electricity/10.csv','a') as secondfile: 
    
    for line in firstfile: 
     
      #  print (line2)
        secondfile.write(line)

# %%
import re
#copia el contenido de un fichero en otro
with open('microwave.csv','r') as firstfile, open('./data/ozm1/electricity/3.csv','a') as secondfile: 
    
    for line in firstfile: 
     
      #  print (line2)
        secondfile.write(line)

# %%
import re
#copia el contenido de un fichero en otro
with open('oil_heater.csv','r') as firstfile, open('./data/ozm1/electricity/7.csv','a') as secondfile: 
    
    for line in firstfile: 
         #  print (line2)
        secondfile.write(line)

# %%
import re
#copia el contenido de un fichero en otro
with open('oven.csv','r') as firstfile, open('./data/ozm1/electricity/2.csv','a') as secondfile: 
    
    for line in firstfile: 
      #  print (line2)
        secondfile.write(line)
